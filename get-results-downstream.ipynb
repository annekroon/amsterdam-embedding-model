# %%
#!/usr/bin/env python3
#DEPENDS: /home/anne/tmpanne/AEM_output/baseline_classreport.json, /home/anne/tmpanne/AEM_output/baseline_classreport.json,
#CREATES: None
#TITLE: Data cleaner (cleans output of ML algorithms)
#DESCRIPTION:Creates a clean data frame with results of ML on different vectorizers, classifiers, and parameter settings.
#PIPE: TRUE

import sys
print(sys.stdin.read().upper())

import seaborn as sns
import matplotlib.pyplot as plt
import json
import logging
import pandas as pd

def get_data(file):
    path_to_data='/home/anne/tmpanne/AEM_output/'

    fname_sml = '{}{}'.format(path_to_data, file)
    with open(fname_sml) as handle:
        class_report =  json.loads(handle.read())

    appended_data = []

    for i in class_report:
        data = pd.DataFrame.from_dict(i)
        appended_data.append(data)
    df = pd.concat(appended_data)
    df['indicators'] = df.index
    return df

def merge_baseline_embedding(dataset):
    df_baseline = get_data('baseline_classreport_dataset_{}_embed_size_large.json'.format(dataset))
    df_embeddings = get_data('embeddings_classreport_dataset_{}_embed_size_large.json'.format(dataset))
    df = pd.concat([df_baseline , df_embeddings])
    return df

def clean_data_metrics(dataset):
    df = merge_baseline_embedding(dataset)
    i = ['precision', 'recall', 'support', 'f1-score']
    df[df['indicators'].isin(i)]
    df.reset_index(inplace=True)
    d = df[df['indicators'].isin(i)].groupby(['classifier', 'model', 'indicators', 'vectorizer']).max()
    return d

def clean_data_parameters(dataset):
    i = ['clf__C', 'clf__fit_intercept', 'clf__loss', 'clf__max_iter','clf__alpha', 'clf__penalty', 'clf__gamma', 'clf__kernel', 'clf__max_features']

    df = merge_baseline_embedding(dataset)
    df = df[df['indicators'].isin(i)].groupby(['classifier', 'model', 'indicators', 'vectorizer']).max()
    df.reset_index(inplace=True)
    e = df.groupby(['classifier', 'model','vectorizer']).apply(lambda g: pd.Series(g.parameters.values, index= + g.indicators.astype(str)))

    parameters = pd.DataFrame(e)
    parameters.reset_index(inplace=True)

    parameters['unique_'] = parameters['classifier'] + "_" + parameters['model']  + "_" +  parameters['vectorizer']

    p = parameters.pivot(index='unique_', columns='indicators', values=0)

    parameters = parameters.groupby(['classifier', 'model', 'vectorizer']).max()
    p.reset_index(inplace=True)
    len(p) == len(parameters)
    parameters.reset_index(inplace=True)
    parameters = pd.merge(p, parameters, on='unique_')
    return parameters

def get_cleaned_data(dataset):
    df = pd.merge(clean_data_metrics(dataset), clean_data_parameters(dataset), on=['classifier','model','vectorizer'], how='left')
    df.rename(columns={'index': 'metrics'}, inplace=True)
    print("..........loaded the data frame........")
    return df

# %%
import sys  
sys.path.append('src/data-processing/')  
from datacleaning import * 
import numpy as np

# %%
output_path = 'output/'

# %%
b =  get_cleaned_data("burscher")
b.head()
b.set_index('model', inplace=True)
# Out:
# ..........loaded the data frame........

# %%
# select metric of interest
df = b[b['metrics'] == 'f1-score']
averaging = 'macro avg'
#averaging = 'weighted avg'
#averaging = 'accuracy'

results = df[df.groupby(['model'])[averaging].transform(max) == df[averaging]].sort_values(averaging)
results[['classifier', 'vectorizer', averaging , 'clf__alpha', 'clf__fit_intercept', 'clf__gamma', 'clf__kernel',
       'clf__loss', 'clf__max_features', 'clf__max_iter', 'clf__penalty']]

results.reset_index(inplace=True)

# %%
ax = sns.catplot(x="macro avg", y="model", edgecolor=".4", data=results, kind="bar",  height=8)
ax.set_titles("{col_name} {col_var}").despine(left=True)
ax.set(xlabel=None, ylabel=None)
ax = sns.set_style("white")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.savefig("{}downstream_Burscher.png".format(output_path),  bbox_inches = 'tight')
# Out:
# No handles with labels found to put in legend.

# %%
v =  get_cleaned_data("vermeer")
v.head()
v.set_index('model', inplace=True)
# Out:
# ..........loaded the data frame........

# %%
# select metric of interest
df = v[v['metrics'] == 'f1-score']
averaging = 'macro avg'

results = df[df.groupby(['model'])[averaging].transform(max) == df[averaging]].sort_values(averaging)
results[['classifier', 'vectorizer', averaging , 'clf__alpha', 'clf__fit_intercept', 'clf__gamma', 'clf__kernel',
       'clf__loss', 'clf__max_features', 'clf__max_iter', 'clf__penalty']]

results.reset_index(inplace=True)

# %%
ax = sns.catplot(x="macro avg", y="model", edgecolor=".4", data=results, kind="bar",  height=8)
ax.set_titles("{col_name} {col_var}").despine(left=True)
ax.set(xlabel=None, ylabel=None)
ax = sns.set_style("white")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.savefig("{}downstream_Vermeer.png".format(output_path),  bbox_inches = 'tight')
# Out:
# No handles with labels found to put in legend.

# %%
ax = sns.catplot(x="9", y="model", edgecolor=".4", data=results, kind="bar",  height=8)
ax.set_titles("{col_name} {col_var}").despine(left=True)
ax.set(xlabel=None, ylabel=None)
ax = sns.set_style("white")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-303d3a78ff62> in <module>()
# ----> 1 ax = sns.catplot(x="9", y="model", edgecolor=".4", data=results, kind="bar",  height=8)
#       2 ax.set_titles("{col_name} {col_var}").despine(left=True)
#       3 ax.set(xlabel=None, ylabel=None)
#       4 ax = sns.set_style("white")
#       5 plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3714     # facets to ensure representation of all data in the final plot
#    3715     p = _CategoricalPlotter()
# -> 3716     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3717     order = p.group_names
#    3718     hue_order = p.hue_names
#
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input '9'

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-d6aa2ca6ad5a> in <module>()
# ----> 1 ax = sns.catplot(x="macro avg", y="model", edgecolor=".4", data=results, kind="bar",  height=8)
#       2 ax.set_titles("{col_name} {col_var}").despine(left=True)
#       3 ax.set(xlabel=None, ylabel=None)
#       4 ax = sns.set_style("white")
#       5 plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3714     # facets to ensure representation of all data in the final plot
#    3715     p = _CategoricalPlotter()
# -> 3716     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3717     order = p.group_names
#    3718     hue_order = p.hue_names
#
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'model'

# %%
ax = sns.catplot(x="9", y="model", edgecolor=".4", data=results, kind="bar",  height=8)
ax.set_titles("{col_name} {col_var}").despine(left=True)
ax.set(xlabel=None, ylabel=None)
ax = sns.set_style("white")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# No handles with labels found to put in legend.

# %%
pathtodata='/home/anne/tmpanne/AEM_output'
dataset = 'vermeer'
classifier = 'SGDClassifier'

base = "{}/embeddings_true_predicted_dataset_{}_embed_size_large.json".format(pathtodata, dataset)
print(base)
df = pd.read_json(base)
#df = df[df['Classifier'] == classifier]
#return df
df
# Out:
# /home/anne/tmpanne/AEM_output/embeddings_true_predicted_dataset_vermeer_embed_size_large.json
#                                                 actual         classifier  \
# 0    [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...        BernoulliNB
# 1    [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...  Passive Agressive
# 10   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...        BernoulliNB
# 100  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...        BernoulliNB
# 101  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...  Passive Agressive
# 102  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...      SGDClassifier
# 103  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                SVM
# 104  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                 ET
# 105  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...        BernoulliNB
# 106  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...  Passive Agressive
# 107  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...      SGDClassifier
# 108  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                SVM
# 109  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                 ET
# 11   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...  Passive Agressive
# 110  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...        BernoulliNB
# 111  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...  Passive Agressive
# 112  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...      SGDClassifier
# 113  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                SVM
# 114  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                 ET
# 115  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...        BernoulliNB
# 116  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...  Passive Agressive
# 117  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...      SGDClassifier
# 118  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                SVM
# 119  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                 ET
# 12   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...      SGDClassifier
# 120  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...        BernoulliNB
# 121  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...  Passive Agressive
# 122  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...      SGDClassifier
# 123  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                SVM
# 124  [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                 ET
# ..                                                 ...                ...
# 72   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...      SGDClassifier
# 73   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                SVM
# 74   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                 ET
# 75   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...        BernoulliNB
# 76   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...  Passive Agressive
# 77   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...      SGDClassifier
# 78   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                SVM
# 79   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                 ET
# 8    [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                SVM
# 80   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...        BernoulliNB
# 81   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...  Passive Agressive
# 82   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...      SGDClassifier
# 83   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                SVM
# 84   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                 ET
# 85   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...        BernoulliNB
# 86   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...  Passive Agressive
# 87   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...      SGDClassifier
# 88   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                SVM
# 89   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                 ET
# 9    [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                 ET
# 90   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...        BernoulliNB
# 91   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...  Passive Agressive
# 92   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...      SGDClassifier
# 93   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                SVM
# 94   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                 ET
# 95   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...        BernoulliNB
# 96   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...  Passive Agressive
# 97   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...      SGDClassifier
# 98   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                SVM
# 99   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 4, 3, 3, 3, ...                 ET
#
#                                                  model  \
# 0                                          wiki.nl.vec
# 1                                          wiki.nl.vec
# 10       w2v_model_nr_5_window_10_size_300_negsample_5
# 100                                        cow-320.txt
# 101                                        cow-320.txt
# 102                                        cow-320.txt
# 103                                        cow-320.txt
# 104                                        cow-320.txt
# 105                                        cow-320.txt
# 106                                        cow-320.txt
# 107                                        cow-320.txt
# 108                                        cow-320.txt
# 109                                        cow-320.txt
# 11       w2v_model_nr_5_window_10_size_300_negsample_5
# 110     w2v_model_nr_6_window_10_size_100_negsample_15
# 111     w2v_model_nr_6_window_10_size_100_negsample_15
# 112     w2v_model_nr_6_window_10_size_100_negsample_15
# 113     w2v_model_nr_6_window_10_size_100_negsample_15
# 114     w2v_model_nr_6_window_10_size_100_negsample_15
# 115     w2v_model_nr_6_window_10_size_100_negsample_15
# 116     w2v_model_nr_6_window_10_size_100_negsample_15
# 117     w2v_model_nr_6_window_10_size_100_negsample_15
# 118     w2v_model_nr_6_window_10_size_100_negsample_15
# 119     w2v_model_nr_6_window_10_size_100_negsample_15
# 12       w2v_model_nr_5_window_10_size_300_negsample_5
# 120      w2v_model_nr_2_window_5_size_100_negsample_15
# 121      w2v_model_nr_2_window_5_size_100_negsample_15
# 122      w2v_model_nr_2_window_5_size_100_negsample_15
# 123      w2v_model_nr_2_window_5_size_100_negsample_15
# 124      w2v_model_nr_2_window_5_size_100_negsample_15
# ..                                                 ...
# 72       w2v_model_nr_3_window_5_size_300_negsample_15
# 73       w2v_model_nr_3_window_5_size_300_negsample_15
# 74       w2v_model_nr_3_window_5_size_300_negsample_15
# 75       w2v_model_nr_3_window_5_size_300_negsample_15
# 76       w2v_model_nr_3_window_5_size_300_negsample_15
# 77       w2v_model_nr_3_window_5_size_300_negsample_15
# 78       w2v_model_nr_3_window_5_size_300_negsample_15
# 79       w2v_model_nr_3_window_5_size_300_negsample_15
# 8                                          wiki.nl.vec
# 80   w2v_model_nr_10_window_47615_size_100_negsampl...
# 81   w2v_model_nr_10_window_47615_size_100_negsampl...
# 82   w2v_model_nr_10_window_47615_size_100_negsampl...
# 83   w2v_model_nr_10_window_47615_size_100_negsampl...
# 84   w2v_model_nr_10_window_47615_size_100_negsampl...
# 85   w2v_model_nr_10_window_47615_size_100_negsampl...
# 86   w2v_model_nr_10_window_47615_size_100_negsampl...
# 87   w2v_model_nr_10_window_47615_size_100_negsampl...
# 88   w2v_model_nr_10_window_47615_size_100_negsampl...
# 89   w2v_model_nr_10_window_47615_size_100_negsampl...
# 9                                          wiki.nl.vec
# 90      w2v_model_nr_7_window_10_size_300_negsample_15
# 91      w2v_model_nr_7_window_10_size_300_negsample_15
# 92      w2v_model_nr_7_window_10_size_300_negsample_15
# 93      w2v_model_nr_7_window_10_size_300_negsample_15
# 94      w2v_model_nr_7_window_10_size_300_negsample_15
# 95      w2v_model_nr_7_window_10_size_300_negsample_15
# 96      w2v_model_nr_7_window_10_size_300_negsample_15
# 97      w2v_model_nr_7_window_10_size_300_negsample_15
# 98      w2v_model_nr_7_window_10_size_300_negsample_15
# 99      w2v_model_nr_7_window_10_size_300_negsample_15
#
#                                              predicted vectorizer
# 0    [3, 1, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 1    [3, 2, 1, 2, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# 10   [3, 2, 1, 3, 1, 3, 1, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 100  [3, 2, 3, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# 101  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 102  [3, 2, 1, 2, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# 103  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 104  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# 105  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 106  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 107  [3, 2, 1, 2, 1, 3, 2, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 108  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 109  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 11   [3, 2, 1, 2, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# 110  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 2, 1, 3, 3, 3, ...  w2v_count
# 111  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 112  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 113  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# 114  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 115  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 116  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 117  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 118  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 119  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_tfidf
# 12   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 120  [3, 1, 1, 3, 1, 3, 1, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# 121  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 122  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 123  [3, 2, 1, 3, 1, 3, 3, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# 124  [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# ..                                                 ...        ...
# 72   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 73   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# 74   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# 75   [3, 2, 1, 4, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_tfidf
# 76   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 77   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 78   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_tfidf
# 79   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_tfidf
# 8    [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 80   [3, 2, 2, 3, 1, 3, 1, 3, 1, 3, 1, 2, 3, 3, 3, ...  w2v_count
# 81   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 82   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 83   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# 84   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 85   [3, 2, 1, 4, 1, 3, 1, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_tfidf
# 86   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 87   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 88   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 89   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 9    [3, 3, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 90   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# 91   [3, 2, 1, 1, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 92   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 93   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_count
# 94   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_count
# 95   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_tfidf
# 96   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 97   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
# 98   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 2, 3, 3, 3, ...  w2v_tfidf
# 99   [3, 2, 1, 3, 1, 3, 4, 3, 1, 3, 3, 1, 3, 3, 3, ...  w2v_tfidf
#
# [140 rows x 5 columns]

# %%
df = pd.read_json('/home/anne/tmpanne/AEM_output/embeddings_true_predicted_dataset_vermeer_embed_size_large.json')

# %%
class get_heatmaps():
    '''Get those heatmaps'''

    def __init__(self, approach, sample, classifier = None, vect=None):
        self.approach = approach
        self.sample = sample
        self.classifier = classifier
        self.vect = vect

    def get_data(self):

        base = "{}/embeddings_true_predicted_dataset_{}_embed_size_large.json".format(pathtodata, dataset)
        df = pd.read_json(base)
        df = df[df['classifier'] == self.classifier]
        return df

    def confusion_matrix(self):
        df = self.get_data()
        df.replace(self.translator, inplace=True)
        df.replace(d2, inplace=True)
        confusion_matrix = pd.crosstab(df['Actual label'], df['Predicted label'], rownames=['True'], colnames=['Predicted'])
        cmn = confusion_matrix.astype('float') / confusion_matrix.sum(axis=1)[:, np.newaxis]
        return cmn

    def get_heatmap(self):
        label = "Values in the diagonal represent the relative times that the manual coding (’true label’ - Y axis ) is equal to the classifier (X axis). Diagonal values indicate the relative number of correct predictions: The higher the values in diagonal, the better the prediction. Off-diagonal values indicate misclassification. Darker colours indicate higher values. Due to class imbalance, values are normalised to facilitate visual understanding. Values below 0.1 are not visualised. "
        cmn = self.confusion_matrix()
        cmn = cmn.round(1)
        fig, ax = plt.subplots(figsize=(10,10))
        heatmap = sns.heatmap(cmn, annot=True, annot_kws={"size": 10}, fmt='.1f',  cmap="BuGn", mask=(cmn<0.1))
    #    heatmap = sns.heatmap(cmn, annot=True, annot_kws={"size": 10}, fmt='.1f',  cmap="gist_gray_r", linecolor='black', mask=(cmn<0.1))
        for _, spine in heatmap.spines.items():
            spine.set_visible(True)
        fs = 16
        heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fs)
        heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fs)
        #plt.title("Normalized Confusion Matrix (Classifier: {}) ".format(self.approach), fontsize= 16)
        plt.title(None)
        plt.ylabel('True label (Manual coding)', fontsize=fs)
        plt.xlabel('Predicted label', fontsize=fs)
        return fig

    def get_figure_save(self):
        #logger.info('{}'.format(label))
        figure = self.get_heatmap()
        if self.approach == 'SML':
            fname = '{}Heatmap_{}_{}_{}'.format(OUTPUTFIGURES, self.approach, self.classifier, self.sample)
        else:
             fname = '{}Heatmap_{}_{}'.format(OUTPUTFIGURES, self.approach, self.sample)
        figure.savefig(fname, bbox_inches='tight')
        print('Saved figure as: {}'.format(fname))

# %%
pathtodata='/home/anne/tmpanne/AEM_output'
dataset = 'vermeer'
classifier = 'SGDClassifier'


a = get_heatmaps(classifier='SGDClassifier', vect='w2v_count', approach = 'SML', sample='Vermeer')

# %%
a.get_heatmap()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-1037c3d79865> in <module>()
# ----> 1 a.get_heatmap()
#
# <ipython-input-75-6565374f3b51> in get_heatmap(self)
#      27     def get_heatmap(self):
#      28         label = "Values in the diagonal represent the relative times that the manual coding (’true label’ - Y axis ) is equal to the classifier (X axis). Diagonal values indicate the relative number of correct predictions: The higher the values in diagonal, the better the prediction. Off-diagonal values indicate misclassification. Darker colours indicate higher values. Due to class imbalance, values are normalised to facilitate visual understanding. Values below 0.1 are not visualised. "
# ---> 29         cmn = self.confusion_matrix()
#      30         cmn = cmn.round(1)
#      31         fig, ax = plt.subplots(figsize=(10,10))
#
# <ipython-input-75-6565374f3b51> in confusion_matrix(self)
#      19     def confusion_matrix(self):
#      20         df = self.get_data()
# ---> 21         df.replace(self.translator, inplace=True)
#      22         df.replace(d2, inplace=True)
#      23         confusion_matrix = pd.crosstab(df['Actual label'], df['Predicted label'], rownames=['True'], colnames=['Predicted'])
#
# AttributeError: 'get_heatmaps' object has no attribute 'translator'

# %%
# select metric of interest
df = v[v['metrics'] == 'f1-score']
averaging = 'micro avg'

results = df[df.groupby(['model'])[averaging].transform(max) == df[averaging]].sort_values(averaging)

results[['classifier', 'vectorizer', averaging , 'clf__alpha', 'clf__fit_intercept', 'clf__gamma', 'clf__kernel',
       'clf__loss', 'clf__max_features', 'clf__max_iter', 'clf__penalty']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6b49cd042ca4> in <module>()
#       1 # select metric of interest
# ----> 2 df = v[v['metrics'] == 'f1-score']
#       3 averaging = 'micro avg'
#       4
#       5 results = df[df.groupby(['model'])[averaging].transform(max) == df[averaging]].sort_values(averaging)
#
# NameError: name 'v' is not defined

# %%
df.head()
df.set_index('model', inplace=True)
# Out:
#   classifier     model vectorizer    metrics         1         2         3  \
# 0         ET  baseline      Count   f1-score  0.700422  0.458333  0.816374
# 1         ET  baseline      Tfidf   f1-score  0.735043  0.494737  0.815155
# 2         ET  baseline      Count  precision  0.674797  0.354839  0.930667
# 3         ET  baseline      Tfidf  precision  0.699187  0.379032  0.946667
# 4         ET  baseline      Count     recall  0.728070  0.647059  0.727083
#
#           4  macro avg  micro avg  ...  clf__C  clf__alpha clf__fit_intercept  \
# 0  0.535714   0.627711   0.724928  ...     NaN         NaN                NaN
# 1  0.475248   0.630046   0.733524  ...     NaN         NaN                NaN
# 2  0.394737   0.588760   0.724928  ...     NaN         NaN                NaN
# 3  0.315789   0.585169   0.733524  ...     NaN         NaN                NaN
# 4  0.833333   0.733886   0.724928  ...     NaN         NaN                NaN
#
#   clf__gamma clf__kernel clf__loss clf__max_features clf__max_iter  \
# 0        NaN         NaN       NaN              auto           NaN
# 1        NaN         NaN       NaN              auto           NaN
# 2        NaN         NaN       NaN              auto           NaN
# 3        NaN         NaN       NaN              auto           NaN
# 4        NaN         NaN       NaN              auto           NaN
#
#   clf__penalty         indicators
# 0          NaN  clf__max_features
# 1          NaN  clf__max_features
# 2          NaN  clf__max_features
# 3          NaN  clf__max_features
# 4          NaN  clf__max_features
#
# [5 rows x 23 columns]

# %%
# select metric of interest
df = df[df['metrics'] == 'f1-score']

results = df[df.groupby(['model'])['weighted avg'].transform(max) == df['weighted avg']].sort_values('weighted avg')
results[['classifier', 'vectorizer', 'weighted avg', 'clf__alpha', 'clf__fit_intercept', 'clf__gamma', 'clf__kernel',
       'clf__loss', 'clf__max_features', 'clf__max_iter', 'clf__penalty']]
# Out:
#                                                            classifier  \
# model
# w2v_model_nr_10_window_47615_size_100_negsample_15      SGDClassifier
# w2v_model_nr_2_window_5_size_100_negsample_15                     SVM
# baseline                                            Passive Agressive
# w2v_model_nr_8_window_47615_size_100_negsample_5        SGDClassifier
# wiki.nl.vec                                             SGDClassifier
# cow-320.txt                                                       SVM
# w2v_model_nr_1_window_5_size_300_negsample_5                      SVM
# w2v_model_nr_3_window_5_size_300_negsample_15                     SVM
# w2v_model_nr_4_window_10_size_100_negsample_5                     SVM
# w2v_model_nr_0_window_5_size_100_negsample_5        Passive Agressive
# w2v_model_nr_7_window_10_size_300_negsample_15          SGDClassifier
# w2v_model_nr_6_window_10_size_100_negsample_15          SGDClassifier
# w2v_model_nr_11_window_47615_size_300_negsample_15  Passive Agressive
# w2v_model_nr_5_window_10_size_300_negsample_5                     SVM
# w2v_model_nr_9_window_47615_size_300_negsample_5    Passive Agressive
#
#                                                    vectorizer  weighted avg  \
# model
# w2v_model_nr_10_window_47615_size_100_negsample_15  w2v_count      0.817128
# w2v_model_nr_2_window_5_size_100_negsample_15       w2v_tfidf      0.817608
# baseline                                                Tfidf      0.819430
# w2v_model_nr_8_window_47615_size_100_negsample_5    w2v_tfidf      0.821569
# wiki.nl.vec                                         w2v_count      0.823054
# cow-320.txt                                         w2v_tfidf      0.826648
# w2v_model_nr_1_window_5_size_300_negsample_5        w2v_tfidf      0.826838
# w2v_model_nr_3_window_5_size_300_negsample_15       w2v_tfidf      0.826907
# w2v_model_nr_4_window_10_size_100_negsample_5       w2v_tfidf      0.826925
# w2v_model_nr_0_window_5_size_100_negsample_5        w2v_tfidf      0.828821
# w2v_model_nr_7_window_10_size_300_negsample_15      w2v_tfidf      0.829659
# w2v_model_nr_6_window_10_size_100_negsample_15      w2v_tfidf      0.831459
# w2v_model_nr_11_window_47615_size_300_negsample_15  w2v_tfidf      0.832206
# w2v_model_nr_5_window_10_size_300_negsample_5       w2v_tfidf      0.832312
# w2v_model_nr_9_window_47615_size_300_negsample_5    w2v_tfidf      0.835331
#
#                                                    clf__alpha  \
# model
# w2v_model_nr_10_window_47615_size_100_negsample_15       0.01
# w2v_model_nr_2_window_5_size_100_negsample_15             NaN
# baseline                                                  NaN
# w2v_model_nr_8_window_47615_size_100_negsample_5         0.01
# wiki.nl.vec                                             1e-05
# cow-320.txt                                               NaN
# w2v_model_nr_1_window_5_size_300_negsample_5              NaN
# w2v_model_nr_3_window_5_size_300_negsample_15             NaN
# w2v_model_nr_4_window_10_size_100_negsample_5             NaN
# w2v_model_nr_0_window_5_size_100_negsample_5              NaN
# w2v_model_nr_7_window_10_size_300_negsample_15           0.01
# w2v_model_nr_6_window_10_size_100_negsample_15           0.01
# w2v_model_nr_11_window_47615_size_300_negsample_15        NaN
# w2v_model_nr_5_window_10_size_300_negsample_5             NaN
# w2v_model_nr_9_window_47615_size_300_negsample_5          NaN
#
#                                                    clf__fit_intercept  \
# model
# w2v_model_nr_10_window_47615_size_100_negsample_15                NaN
# w2v_model_nr_2_window_5_size_100_negsample_15                     NaN
# baseline                                                         True
# w2v_model_nr_8_window_47615_size_100_negsample_5                  NaN
# wiki.nl.vec                                                       NaN
# cow-320.txt                                                       NaN
# w2v_model_nr_1_window_5_size_300_negsample_5                      NaN
# w2v_model_nr_3_window_5_size_300_negsample_15                     NaN
# w2v_model_nr_4_window_10_size_100_negsample_5                     NaN
# w2v_model_nr_0_window_5_size_100_negsample_5                    False
# w2v_model_nr_7_window_10_size_300_negsample_15                    NaN
# w2v_model_nr_6_window_10_size_100_negsample_15                    NaN
# w2v_model_nr_11_window_47615_size_300_negsample_15              False
# w2v_model_nr_5_window_10_size_300_negsample_5                     NaN
# w2v_model_nr_9_window_47615_size_300_negsample_5                False
#
#                                                    clf__gamma clf__kernel  \
# model
# w2v_model_nr_10_window_47615_size_100_negsample_15        NaN         NaN
# w2v_model_nr_2_window_5_size_100_negsample_15           0.001         rbf
# baseline                                                  NaN         NaN
# w2v_model_nr_8_window_47615_size_100_negsample_5          NaN         NaN
# wiki.nl.vec                                               NaN         NaN
# cow-320.txt                                             0.001      linear
# w2v_model_nr_1_window_5_size_300_negsample_5            0.001         rbf
# w2v_model_nr_3_window_5_size_300_negsample_15           0.001         rbf
# w2v_model_nr_4_window_10_size_100_negsample_5           0.001         rbf
# w2v_model_nr_0_window_5_size_100_negsample_5              NaN         NaN
# w2v_model_nr_7_window_10_size_300_negsample_15            NaN         NaN
# w2v_model_nr_6_window_10_size_100_negsample_15            NaN         NaN
# w2v_model_nr_11_window_47615_size_300_negsample_15        NaN         NaN
# w2v_model_nr_5_window_10_size_300_negsample_5           0.001         rbf
# w2v_model_nr_9_window_47615_size_300_negsample_5          NaN         NaN
#
#                                                         clf__loss  \
# model
# w2v_model_nr_10_window_47615_size_100_negsample_15            NaN
# w2v_model_nr_2_window_5_size_100_negsample_15                 NaN
# baseline                                                    hinge
# w2v_model_nr_8_window_47615_size_100_negsample_5              NaN
# wiki.nl.vec                                                   NaN
# cow-320.txt                                                   NaN
# w2v_model_nr_1_window_5_size_300_negsample_5                  NaN
# w2v_model_nr_3_window_5_size_300_negsample_15                 NaN
# w2v_model_nr_4_window_10_size_100_negsample_5                 NaN
# w2v_model_nr_0_window_5_size_100_negsample_5                hinge
# w2v_model_nr_7_window_10_size_300_negsample_15                NaN
# w2v_model_nr_6_window_10_size_100_negsample_15                NaN
# w2v_model_nr_11_window_47615_size_300_negsample_15  squared_hinge
# w2v_model_nr_5_window_10_size_300_negsample_5                 NaN
# w2v_model_nr_9_window_47615_size_300_negsample_5            hinge
#
#                                                    clf__max_features  \
# model
# w2v_model_nr_10_window_47615_size_100_negsample_15               NaN
# w2v_model_nr_2_window_5_size_100_negsample_15                    NaN
# baseline                                                         NaN
# w2v_model_nr_8_window_47615_size_100_negsample_5                 NaN
# wiki.nl.vec                                                      NaN
# cow-320.txt                                                      NaN
# w2v_model_nr_1_window_5_size_300_negsample_5                     NaN
# w2v_model_nr_3_window_5_size_300_negsample_15                    NaN
# w2v_model_nr_4_window_10_size_100_negsample_5                    NaN
# w2v_model_nr_0_window_5_size_100_negsample_5                     NaN
# w2v_model_nr_7_window_10_size_300_negsample_15                   NaN
# w2v_model_nr_6_window_10_size_100_negsample_15                   NaN
# w2v_model_nr_11_window_47615_size_300_negsample_15               NaN
# w2v_model_nr_5_window_10_size_300_negsample_5                    NaN
# w2v_model_nr_9_window_47615_size_300_negsample_5                 NaN
#
#                                                    clf__max_iter clf__penalty
# model
# w2v_model_nr_10_window_47615_size_100_negsample_15            30   elasticnet
# w2v_model_nr_2_window_5_size_100_negsample_15                NaN          NaN
# baseline                                                      15          NaN
# w2v_model_nr_8_window_47615_size_100_negsample_5              30           l2
# wiki.nl.vec                                                   30   elasticnet
# cow-320.txt                                                  NaN          NaN
# w2v_model_nr_1_window_5_size_300_negsample_5                 NaN          NaN
# w2v_model_nr_3_window_5_size_300_negsample_15                NaN          NaN
# w2v_model_nr_4_window_10_size_100_negsample_5                NaN          NaN
# w2v_model_nr_0_window_5_size_100_negsample_5                  10          NaN
# w2v_model_nr_7_window_10_size_300_negsample_15                30           l2
# w2v_model_nr_6_window_10_size_100_negsample_15                30   elasticnet
# w2v_model_nr_11_window_47615_size_300_negsample_15             5          NaN
# w2v_model_nr_5_window_10_size_300_negsample_5                NaN          NaN
# w2v_model_nr_9_window_47615_size_300_negsample_5              15          NaN
